# %% [markdown]
# # Development of a NLP

# %% [markdown]
# ## Tokenisation

# %% [markdown]
# ## TF-IDF

# %% [markdown]
# ## Word2Vec

# %% [markdown]
# ## Modèles séquentiels

# %% [markdown]
# ## LLMs
